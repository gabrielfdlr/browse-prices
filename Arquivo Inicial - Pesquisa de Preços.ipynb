# %% [markdown]
# # Projeto Automação Web - Busca de Preços
#
# ### Objetivo: treinar um projeto em que a gente tenha que usar automações web com Selenium para buscar as informações que precisamos
#
# - Já fizemos um projeto com esse objetivo no Módulo de Python e Web e em gravações de encontros ao vivo, mas não custa nada treinar mais um pouco.
#
# ### Como vai funcionar:
#
# - Imagina que você trabalha na área de compras de uma empresa e precisa fazer uma comparação de fornecedores para os seus insumos/produtos.
#
# - Nessa hora, você vai constantemente buscar nos sites desses fornecedores os produtos disponíveis e o preço, afinal, cada um deles pode fazer promoção em momentos diferentes e com valores diferentes.
#
# - Seu objetivo: Se o valor dos produtos for abaixo de um preço limite definido por você, você vai descobrir os produtos mais baratos e atualizar isso em uma planilha.
# - Em seguida, vai enviar um e-mail com a lista dos produtos abaixo do seu preço máximo de compra.
#
# - No nosso caso, vamos fazer com produtos comuns em sites como Google Shopping e Buscapé, mas a ideia é a mesma para outros sites.
#
# ### Outra opção:
#
# - APIs
#
# ### O que temos disponível?
#
# - Planilha de Produtos, com os nomes dos produtos, o preço máximo, o preço mínimo (para evitar produtos "errados" ou "baratos de mais para ser verdade" e os termos que vamos querer evitar nas nossas buscas.
#
# ### O que devemos fazer:
#
# - Procurar cada produto no Google Shopping e pegar todos os resultados que tenham preço dentro da faixa e sejam os produtos corretos
# - O mesmo para o Buscapé
# - Enviar um e-mail para o seu e-mail (no caso da empresa seria para a área de compras por exemplo) com a notificação e a tabela com os itens e preços encontrados, junto com o link de compra. (Vou usar o e-mail pythonimpressionador@gmail.com. Use um e-mail seu para fazer os testes para ver se a mensagem está chegando)

# %% [markdown]
# #### Preparar e abrir o Navegador

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
import email.message
from email import encoders
import pandas as pd
import time

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %% [markdown]
# #### Busca no Google

# %%
def busca_google(item, evitar, p_min, p_max):
    navegador.get("https://www.google.com/")
    texto_busca = f'"{item}"'
    for palavra in evitar:
        texto_busca += ' -' + palavra
    navegador.find_element(By.CLASS_NAME, 'gLFyf').send_keys(texto_busca)
    navegador.find_element(By.CLASS_NAME, 'gLFyf').send_keys(Keys.ENTER)
    menu = navegador.find_elements(By.CLASS_NAME, 'hdtb-mitem')
    for botao in menu:
        if 'Shopping' in botao.text:
            botao.click()
            break
    dic_item = {}
    lista_dics = []
    try:
        destaque = navegador.find_element(By.CLASS_NAME, 'sh-dp__sc')
        p_mel_cor = destaque.find_element(By.CLASS_NAME, '_-p8').text
        if len(p_mel_cor) == 11:
            p_mel_cor_val = float(p_mel_cor[3:11].replace('.','').replace(',','.'))
            if p_mel_cor_val >= p_min and p_mel_cor_val < p_max:
                dic_item = {}
                dic_item['nome'] = destaque.find_element(By.CLASS_NAME, 'sh-t__title-popout').text
                dic_item['preco'] = p_mel_cor
                dic_item['link'] = destaque.find_element(By.CLASS_NAME, 'sh-t__title-popout').get_attribute('href')
                print(dic_item)
                lista_dics.append(dic_item)
            else:
                print('Preço do destaque fora do intervalo')
        else:
            print('Preço do destaque não tem 11 caracteres')
    except:
        print('Destaque não encontrado')
    anuncios = navegador.find_elements(By.CLASS_NAME, 'i0X6df')
    print(len(anuncios))
    for i, anuncio in enumerate(anuncios):
        preco = anuncio.find_element(By.CLASS_NAME, 'a8Pemb').text
        if len(preco) == 11:
            preco_val = float(preco[3:11].replace('.','').replace(',','.'))
            if preco_val >= p_min and preco_val < p_max:
                dic_item = {}
                dic_item['nome'] = anuncio.find_element(By.CLASS_NAME, 'tAxDx').text
                dic_item['preco'] = preco
                dic_item['link'] = anuncio.find_element(By.CLASS_NAME, 'Lq5OHe').get_attribute('href')
                print(dic_item)
                lista_dics.append(dic_item)
            else:
                print(f'Preço do anuncio {i} fora do intervalo. Preço: {preco}')
        else:
            print(f'Preço do anuncio {i} não tem 11 caracteres. Preço: {preco}')
    return lista_dics

# %% [markdown]
# #### Busca no Buscapé

# %%
def busca_buscape(item, evitar, p_min, p_max):
    navegador.get("https://www.buscape.com.br/")
    navegador.find_element(By.XPATH, '//*[@id="new-header"]/div[1]/div/div/div[3]/div/div/div[2]/div/div[1]/input').send_keys(item)
    navegador.find_element(By.XPATH, '//*[@id="new-header"]/div[1]/div/div/div[3]/div/div/div[2]/div/div[1]/input').send_keys(Keys.ENTER)
    time.sleep(5)
    anuncios = navegador.find_elements(By.CLASS_NAME, 'SearchCard_ProductCard_Inner__7JhKb')
    dic_item = {}
    lista_dics = []
    print(len(anuncios))
    for i, anuncio in enumerate(anuncios):
        nome_prod = anuncio.find_element(By.CLASS_NAME, 'SearchCard_ProductCard_Name__ZaO5o').text
        check_evitar = False
        for palavra in evitar:
            if palavra in nome_prod.lower():
                check_evitar = True
                print(f'Encontramos "{palavra}" no nome do item {nome_prod}.')
        if check_evitar == False:
            preco = anuncio.find_element(By.CLASS_NAME, 'Text_MobileHeadingS__Zxam2').text
            if len(preco) == 11:
                preco_val = float(preco[3:11].replace('.','').replace(',','.'))
                if preco_val >= p_min and preco_val < p_max:
                    dic_item = {}
                    dic_item['nome'] = nome_prod
                    dic_item['preco'] = preco
                    dic_item['link'] = anuncio.get_attribute('href')
                    print(dic_item)
                    lista_dics.append(dic_item)
                else:
                    print(f'Preço do anuncio {i} fora do intervalo. Preço: {preco}')
            else:
                print(f'Preço do anuncio {i} não tem 11 caracteres. Preço: {preco}')
    return lista_dics

# %% [markdown]
# #### Enviar email

# %%
def enviar_email(produto, tabela_ofertas):
    corpo_email = f'''
    <p>Prezados,</p>
    <p></p>
    <p>Encontramos as seguintes ofertas para o produto {produto} dentro das especificações fornecidas:</p>
    <p>{tabela_ofertas.to_html(index=False)}</p>
    <p></p>
    <p>Estamos à disposição para quaisquer dúvidas.</p>
    <p></p>
    <p>Att.,</p>
    <p>Gabriel de La Rocha</p>
    '''
    
    msg = MIMEMultipart()
    msg['Subject'] = f"Ofertas do Dia - {produto}"
    msg['From'] = 'gabrieldelarocha@gmail.com'
    msg['To'] = 'gabriel.delarocha@consultoriadoamanha.com.br'
    password = 'cbkclecoejvlaopt' 
    msg.add_header('Content-Type', 'html')
    msg.attach(MIMEText(corpo_email, 'html'))
    
    s = smtplib.SMTP('smtp.gmail.com: 587')
    s.starttls()
    # Login Credentials for sending the mail
    s.login(msg['From'], password)
    s.sendmail(msg['From'], [msg['To']], msg.as_string())
    print(f'Email do produto {produto} enviado')

# %% [markdown]
# #### Preparar buscas

# %%
buscas_df = pd.read_excel('buscas.xlsx')
for i, item in enumerate(buscas_df['Nome']):
    evitar = []
    lista_google = []
    lista_buscape = []
    lista_buscas = []
    texto_evitar = buscas_df.loc[i, 'Termos banidos'].split()
    for palavra in texto_evitar:
        evitar.append(palavra)
    p_min = float(buscas_df.loc[i, 'Preço mínimo'])
    p_max = float(buscas_df.loc[i, 'Preço máximo'])
    lista_google = busca_google(item, evitar, p_min, p_max)
    lista_buscape = busca_buscape(item, evitar, p_min, p_max)
    lista_buscas = lista_google + lista_buscape
    ofertas_df = pd.DataFrame(lista_buscas)
    display(ofertas_df)
    enviar_email(item, ofertas_df)
# Out:
# Destaque não encontrado
# 61
# Preço do anuncio 0 não tem 11 caracteres. Preço:
# Preço do anuncio 1 fora do intervalo. Preço: R$ 1.689,90
# Preço do anuncio 2 fora do intervalo. Preço: R$ 4.139,10
# Preço do anuncio 3 fora do intervalo. Preço: R$ 4.269,00
# {'nome': 'iPhone 12 64GB - Azul - Estou Zerado', 'preco': 'R$ 3.422,51', 'link': 'https://www.google.com/shopping/product/357344828079836893?q=%22iphone+12+64gb%22+-mini+-watch&biw=1036&bih=714&dpr=1.25&prds=eto:2193268644434894717_0,pid:4387230182954649532,rsk:PC_11630641001267601036&sa=X&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ8wIIrAw'}
# Preço do anuncio 5 fora do intervalo. Preço: R$ 7.162,00
# {'nome': 'iPhone 12 64GB - Roxo - Estou Zerado', 'preco': 'R$ 3.422,51', 'link': 'https://www.google.com/shopping/product/1409198851555036304?q=%22iphone+12+64gb%22+-mini+-watch&biw=1036&bih=714&dpr=1.25&prds=eto:8904915105488796308_0,pid:5070126177312031027&sa=X&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ8wIIzww'}
# {'nome': 'Apple Iphone 12 Mini 4gb/64gb 5.4 Azul', 'preco': 'R$ 3.469,49', 'link': 'https://www.google.com/url?url=https://www.tradeinn.com/techinn/pt/apple-iphone-12-mini-4gb-64gb-5.4/137821887/p%3Futm_source%3Dgoogle_products%26utm_medium%3Dmerchant%26id_producte%3D11865374%26country%3Dbr&rct=j&q=&esrc=s&sa=U&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ2SkI4Aw&usg=AOvVaw2iC539oMzCNm5Jbqn5bOBa'}
# {'nome': 'iPhone 12 Mini 64GB - Preto - Estou Zerado', 'preco': 'R$ 3.217,31', 'link': 'https://www.google.com/shopping/product/1218119741731643624?q=%22iphone+12+64gb%22+-mini+-watch&biw=1036&bih=714&dpr=1.25&prds=eto:10485432764164071290_0,pid:13526703606087374262,rsk:PROD_VAR_925660058154905600&sa=X&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ8wII8Aw'}
# Preço do anuncio 9 fora do intervalo. Preço: R$ 2.315,00
# Preço do anuncio 10 fora do intervalo. Preço: R$ 3.700,00
# Preço do anuncio 11 fora do intervalo. Preço: R$ 2.328,15
# Preço do anuncio 12 fora do intervalo. Preço: R$ 6.299,10
# Preço do anuncio 13 fora do intervalo. Preço: R$ 3.847,40
# Preço do anuncio 14 fora do intervalo. Preço: R$ 3.615,00
# Preço do anuncio 15 fora do intervalo. Preço: R$ 3.696,65
# {'nome': 'Apple iPhone 12 64gb 5g Vitrine Original Bateria 100% Nf', 'preco': 'R$ 3.499,00', 'link': 'https://www.google.com/url?url=https://produto.mercadolivre.com.br/MLB-3256026241-apple-iphone-12-64gb-5g-vitrine-original-bateria-100-nf-_JM%3Fmatt_tool%3D18956390%26utm_source%3Dgoogle_shopping%26utm_medium%3Dorganic&rct=j&q=&esrc=s&sa=U&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ2SkI7w0&usg=AOvVaw3K0DjyQBZfcvm10uBPqaUC'}
# Preço do anuncio 17 fora do intervalo. Preço: R$ 2.359,90
# Preço do anuncio 18 fora do intervalo. Preço: R$ 4.049,10
# Preço do anuncio 19 fora do intervalo. Preço: R$ 2.754,05
# Preço do anuncio 20 fora do intervalo. Preço: R$ 4.015,00
# Preço do anuncio 21 não tem 11 caracteres. Preço: R$ 100,00
# {'nome': '(Seminovo) iPhone 12 mini Apple Branco, 64GB', 'preco': 'R$ 3.059,15', 'link': 'https://www.google.com/url?url=https://www.taqi.com.br/seminovo-apple-iphone12mini-64gb-branco/220675%3Fsrsltid%3DAfAwrE5ibnQrdHiLr8CcaH2K10AKtqHNn34N7YMArT2P_74yJyzmBsrWvb4&rct=j&q=&esrc=s&sa=U&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ2SkIzA4&usg=AOvVaw1KN02lzCj4nZk9RP2iu3Op'}
# Preço do anuncio 23 fora do intervalo. Preço: R$ 4.429,00
# Preço do anuncio 24 fora do intervalo. Preço: R$ 4.499,00
# Preço do anuncio 25 fora do intervalo. Preço: R$ 3.715,00
# Preço do anuncio 26 fora do intervalo. Preço: R$ 2.819,00
# {'nome': '(Seminovo) iPhone 12 Mini Apple Preto, 64GB', 'preco': 'R$ 3.059,15', 'link': 'https://www.google.com/url?url=https://www.taqi.com.br/seminovo-apple-iphone-12-mini-64gb-preto-taqi/222836%3Fsrsltid%3DAfAwrE7wcjleROl3AqeIzICayHce6LM76iFGRb_xYp9aChni0EYqYcQMLfE&rct=j&q=&esrc=s&sa=U&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ2SkImA8&usg=AOvVaw0pZ9OXhZkKwCPQ8rjruL9o'}
# {'nome': 'IPhone 11 Apple (64GB) Preto Tela 6,1 4G Câmera 12MP iOS Novo', 'preco': 'R$ 3.200,00', 'link': 'https://www.google.com/url?url=https://www.submarino.com.br/produto/7240586792%3Fopn%3DXMLGOOGLE%26offerId%3D64064815eca21af261d9e87e&rct=j&q=&esrc=s&sa=U&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ2SkIpw8&usg=AOvVaw2_jVF7MoN9mL0rS-Y26amq'}
# {'nome': 'Apple Smartphone iPhone 12 4gb/128gb 6.1 Dual Sim Azul', 'preco': 'R$ 3.377,99', 'link': 'https://www.google.com/shopping/product/10034334009791668212?q=%22iphone+12+64gb%22+-mini+-watch&biw=1036&bih=714&dpr=1.25&prds=eto:13644664496250288034_0,pid:6653376184142581832,rsk:PC_10018870533242825809&sa=X&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ8wIItg8'}
# Preço do anuncio 30 fora do intervalo. Preço: R$ 3.999,00
# Preço do anuncio 31 fora do intervalo. Preço: R$ 4.429,00
# Preço do anuncio 32 fora do intervalo. Preço: R$ 4.347,00
# Preço do anuncio 33 fora do intervalo. Preço: R$ 2.754,05
# Preço do anuncio 34 fora do intervalo. Preço: R$ 6.500,00
# {'nome': 'iPhone 11 Apple 64GB Branco, Tela de 6,1”, Câmera Dupla de 12MP, iOS', 'preco': 'R$ 3.499,90', 'link': 'https://www.google.com/url?url=https://www.fornecedordeprodutos.com/produto/apple-iphone-11-64gb-branco/&rct=j&q=&esrc=s&sa=U&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ2SkIlhA&usg=AOvVaw1jMCd-i9V6jNk57qGsQSnP'}
# Preço do anuncio 36 fora do intervalo. Preço: R$ 4.139,10
# Preço do anuncio 37 fora do intervalo. Preço: R$ 4.749,00
# Preço do anuncio 38 fora do intervalo. Preço: R$ 3.699,00
# Preço do anuncio 39 não tem 11 caracteres. Preço: R$ 100,00
# Preço do anuncio 40 fora do intervalo. Preço: R$ 5.022,00
# Preço do anuncio 41 fora do intervalo. Preço: R$ 4.173,00
# Preço do anuncio 42 fora do intervalo. Preço: R$ 5.699,00
# Preço do anuncio 43 fora do intervalo. Preço: R$ 2.969,10
# Preço do anuncio 44 fora do intervalo. Preço: R$ 4.600,00
# Preço do anuncio 45 fora do intervalo. Preço: R$ 5.499,00
# Preço do anuncio 46 fora do intervalo. Preço: R$ 4.302,54
# Preço do anuncio 47 fora do intervalo. Preço: R$ 4.429,00
# Preço do anuncio 48 não tem 11 caracteres. Preço: R$ 35,00
# Preço do anuncio 49 fora do intervalo. Preço: R$ 4.699,00
# Preço do anuncio 50 fora do intervalo. Preço: R$ 4.399,99
# Preço do anuncio 51 fora do intervalo. Preço: R$ 4.173,00
# {'nome': '(Seminovo) iPhone 12 Apple Preto, 64GB', 'preco': 'R$ 3.144,15', 'link': 'https://www.google.com/url?url=https://www.taqi.com.br/seminovo-iphone12-64gbpreto-internacional/220672%3Fsrsltid%3DAfAwrE7ye9EFIhPjqzgIIP4Kp_85z8gEWdMBYN6u3RpMvltakYTbcZ21-yk&rct=j&q=&esrc=s&sa=U&ved=0ahUKEwiruoKqpoH-AhVzppUCHVbdAwMQ2SkImRI&usg=AOvVaw0MPKyy8JiPwzHMNi6u94PG'}
# Preço do anuncio 53 fora do intervalo. Preço: R$ 2.315,00
# Preço do anuncio 54 fora do intervalo. Preço: R$ 2.754,05
# Preço do anuncio 55 fora do intervalo. Preço: R$ 4.769,10
# Preço do anuncio 56 não tem 11 caracteres. Preço: R$ 429,36
# Preço do anuncio 57 fora do intervalo. Preço: R$ 4.299,00
# Preço do anuncio 58 fora do intervalo. Preço: R$ 3.990,00
# Preço do anuncio 59 fora do intervalo. Preço: R$ 4.099,99
# Preço do anuncio 60 fora do intervalo. Preço: R$ 4.480,00
# 3
# {'nome': 'Smartphone Apple iPhone 12 64GB Câmera Dupla', 'preco': 'R$ 3.480,00', 'link': 'https://www.buscape.com.br/celular/smartphone-apple-iphone-12-64gb-ios?_lc=88&searchterm=iphone%2012%2064gb'}
# Preço do anuncio 1 fora do intervalo. Preço: R$ 6.696,00
# Preço do anuncio 2 fora do intervalo. Preço: R$ 3.869,10
#                                                  nome        preco  \
# 0                iPhone 12 64GB - Azul - Estou Zerado  R$ 3.422,51
# 1                iPhone 12 64GB - Roxo - Estou Zerado  R$ 3.422,51
# 2              Apple Iphone 12 Mini 4gb/64gb 5.4 Azul  R$ 3.469,49
# 3          iPhone 12 Mini 64GB - Preto - Estou Zerado  R$ 3.217,31
# 4   Apple iPhone 12 64gb 5g Vitrine Original Bater...  R$ 3.499,00
# 5        (Seminovo) iPhone 12 mini Apple Branco, 64GB  R$ 3.059,15
# 6         (Seminovo) iPhone 12 Mini Apple Preto, 64GB  R$ 3.059,15
# 7   IPhone 11 Apple (64GB) Preto Tela 6,1 4G Câmer...  R$ 3.200,00
# 8   Apple Smartphone iPhone 12 4gb/128gb 6.1 Dual ...  R$ 3.377,99
# 9   iPhone 11 Apple 64GB Branco, Tela de 6,1”, Câm...  R$ 3.499,90
# 10             (Seminovo) iPhone 12 Apple Preto, 64GB  R$ 3.144,15
# 11       Smartphone Apple iPhone 12 64GB Câmera Dupla  R$ 3.480,00
#
#                                                  link
# 0   https://www.google.com/shopping/product/357344...
# 1   https://www.google.com/shopping/product/140919...
# 2   https://www.google.com/url?url=https://www.tra...
# 3   https://www.google.com/shopping/product/121811...
# 4   https://www.google.com/url?url=https://produto...
# 5   https://www.google.com/url?url=https://www.taq...
# 6   https://www.google.com/url?url=https://www.taq...
# 7   https://www.google.com/url?url=https://www.sub...
# 8   https://www.google.com/shopping/product/100343...
# 9   https://www.google.com/url?url=https://www.for...
# 10  https://www.google.com/url?url=https://www.taq...
# 11  https://www.buscape.com.br/celular/smartphone-...
# Email do produto iphone 12 64gb enviado
# Destaque não encontrado
# 60
# Preço do anuncio 0 fora do intervalo. Preço: R$ 2.399,00
# Preço do anuncio 1 fora do intervalo. Preço: R$ 2.159,99
# Preço do anuncio 2 fora do intervalo. Preço: R$ 2.339,00
# Preço do anuncio 3 fora do intervalo. Preço: R$ 2.799,00
# Preço do anuncio 4 fora do intervalo. Preço: R$ 2.499,99
# Preço do anuncio 5 fora do intervalo. Preço: R$ 3.652,23
# Preço do anuncio 6 fora do intervalo. Preço: R$ 2.413,80
# Preço do anuncio 7 fora do intervalo. Preço: R$ 1.701,69
# Preço do anuncio 8 fora do intervalo. Preço: R$ 2.334,99
# Preço do anuncio 9 fora do intervalo. Preço: R$ 2.479,90
# Preço do anuncio 10 fora do intervalo. Preço: R$ 2.659,99
# Preço do anuncio 11 fora do intervalo. Preço: R$ 2.676,97
# Preço do anuncio 12 fora do intervalo. Preço: R$ 2.778,38
# Preço do anuncio 13 fora do intervalo. Preço: R$ 2.236,02
# Preço do anuncio 14 não tem 11 caracteres. Preço: R$ 1.690,16 + impostos
# Preço do anuncio 15 fora do intervalo. Preço: R$ 3.079,90
# Preço do anuncio 16 fora do intervalo. Preço: R$ 2.599,00
# Preço do anuncio 17 não tem 11 caracteres. Preço: R$ 522,79
# Preço do anuncio 18 fora do intervalo. Preço: R$ 3.499,00
# Preço do anuncio 19 fora do intervalo. Preço: R$ 2.195,00
# Preço do anuncio 20 fora do intervalo. Preço: R$ 2.221,42
# Preço do anuncio 21 fora do intervalo. Preço: R$ 2.669,71
# Preço do anuncio 22 fora do intervalo. Preço: R$ 2.699,00
# Preço do anuncio 23 fora do intervalo. Preço: R$ 1.822,80
# Preço do anuncio 24 não tem 11 caracteres. Preço: R$ 2.343,00 + impostos
# Preço do anuncio 25 fora do intervalo. Preço: R$ 2.399,00
# Preço do anuncio 26 fora do intervalo. Preço: R$ 3.199,00
# Preço do anuncio 27 fora do intervalo. Preço: R$ 2.465,00
# Preço do anuncio 28 fora do intervalo. Preço: R$ 2.899,99
# Preço do anuncio 29 fora do intervalo. Preço: R$ 1.880,49
# Preço do anuncio 30 fora do intervalo. Preço: R$ 1.859,42
# Preço do anuncio 31 fora do intervalo. Preço: R$ 2.699,00
# Preço do anuncio 32 fora do intervalo. Preço: R$ 2.879,00
# Preço do anuncio 33 fora do intervalo. Preço: R$ 2.019,01
# Preço do anuncio 34 fora do intervalo. Preço: R$ 1.900,99
# Preço do anuncio 35 fora do intervalo. Preço: R$ 7.909,00
# Preço do anuncio 36 fora do intervalo. Preço: R$ 2.600,30
# Preço do anuncio 37 não tem 11 caracteres. Preço: R$ 1.599,59 + impostos
# Preço do anuncio 38 fora do intervalo. Preço: R$ 5.401,35
# Preço do anuncio 39 fora do intervalo. Preço: R$ 3.869,91
# Preço do anuncio 40 fora do intervalo. Preço: R$ 1.687,82
# Preço do anuncio 41 fora do intervalo. Preço: R$ 2.871,49
# Preço do anuncio 42 fora do intervalo. Preço: R$ 2.599,00
# Preço do anuncio 43 não tem 11 caracteres. Preço: R$ 2.105,61 + impostos
# Preço do anuncio 44 não tem 11 caracteres. Preço: R$ 17.500,00
# Preço do anuncio 45 fora do intervalo. Preço: R$ 2.198,28
# Preço do anuncio 46 não tem 11 caracteres. Preço: R$ 11.399,90
# Preço do anuncio 47 fora do intervalo. Preço: R$ 2.607,42
# Preço do anuncio 48 fora do intervalo. Preço: R$ 1.202,66
# Preço do anuncio 49 fora do intervalo. Preço: R$ 3.305,99
# Preço do anuncio 50 fora do intervalo. Preço: R$ 3.297,98
# Preço do anuncio 51 fora do intervalo. Preço: R$ 5.479,00
# Preço do anuncio 52 fora do intervalo. Preço: R$ 3.109,25
# Preço do anuncio 53 fora do intervalo. Preço: R$ 3.159,99
# Preço do anuncio 54 não tem 11 caracteres. Preço: R$ 1.961,05 + impostos
# Preço do anuncio 55 fora do intervalo. Preço: R$ 7.955,10
# Preço do anuncio 56 não tem 11 caracteres. Preço: R$ 928,89 + impostos
# Preço do anuncio 57 fora do intervalo. Preço: R$ 2.592,12
# {'nome': 'PC Gamer U3, Ryzen 5 5600g, GeForce RTX 3060, 8GB DDR4, 240gb SSD NVMe, Gabinete ...', 'preco': 'R$ 4.399,89', 'link': 'https://www.google.com/url?url=https://www.lojanovaera.com/produto/pc-gamer-u5-ryzen-5-5600g-geforce-rtx-3060-8gb-ddr4-ssd-240gb-gabinete-lateral-de-vidro.html%3Futm_source%3DSite%26utm_medium%3DGoogleMerchant%26utm_campaign%3DGoogleMerchant%26srsltid%3DAfAwrE7SGzKBcqtoarV2nvPzkY7e8xGm4HHmNsz9zQhUvR45SQeFnBBcGFM&rct=j&q=&esrc=s&sa=U&ved=0ahUKEwiyyei8poH-AhUzp5UCHTzkDI4Q2SkIoRQ&usg=AOvVaw01T-ekniNrI57GXct3RrwH'}
# Preço do anuncio 59 fora do intervalo. Preço: R$ 4.688,50
# 24
# Preço do anuncio 0 fora do intervalo. Preço: R$ 2.692,44
# Preço do anuncio 1 fora do intervalo. Preço: R$ 3.883,52
# Preço do anuncio 2 fora do intervalo. Preço: R$ 2.676,37
# Preço do anuncio 3 fora do intervalo. Preço: R$ 3.299,00
# Preço do anuncio 4 fora do intervalo. Preço: R$ 2.698,40
# {'nome': 'Placa de Video NVIDIA GeForce RTX 3060 12 GB GDDR6 192 Bits Asus TUF-RTX3060-O12G-GAMING', 'preco': 'R$ 4.441,10', 'link': 'https://www.buscape.com.br/placa-de-video/placa-de-video-nvidia-geforce-rtx-3060-12-gb-gddr6-192-bits-asus-tuf-rtx3060-o12g-gaming?_lc=88&searchterm=rtx%203060'}
# Preço do anuncio 6 fora do intervalo. Preço: R$ 5.627,66
# Preço do anuncio 7 fora do intervalo. Preço: R$ 6.859,33
# Preço do anuncio 8 fora do intervalo. Preço: R$ 5.149,00
# Preço do anuncio 9 fora do intervalo. Preço: R$ 4.999,99
# Preço do anuncio 10 fora do intervalo. Preço: R$ 2.159,99
# Preço do anuncio 11 fora do intervalo. Preço: R$ 2.944,99
# Preço do anuncio 12 fora do intervalo. Preço: R$ 2.999,99
# Preço do anuncio 13 fora do intervalo. Preço: R$ 2.439,99
# Preço do anuncio 14 fora do intervalo. Preço: R$ 2.299,99
# Preço do anuncio 15 fora do intervalo. Preço: R$ 2.499,99
# Preço do anuncio 16 fora do intervalo. Preço: R$ 2.699,99
# Preço do anuncio 17 fora do intervalo. Preço: R$ 2.429,99
# {'nome': 'GIGABYTE Placa de vídeo GeForce RTX 3060 Gaming OC 12G (REV2.0), 3X ventiladores WINDFORCE 12GB 192-bit GDDR6, GV-N3060GAMING OC-12GD REV2.0', 'preco': 'R$ 4.499,00', 'link': 'https://www.buscape.com.br/lead?oid=546338771&channel=86&index=12&searchterm=rtx%203060'}
# Preço do anuncio 19 fora do intervalo. Preço: R$ 2.659,99
# Preço do anuncio 20 fora do intervalo. Preço: R$ 2.858,93
# Preço do anuncio 21 fora do intervalo. Preço: R$ 7.511,40
# Preço do anuncio 22 fora do intervalo. Preço: R$ 3.209,99
# Preço do anuncio 23 fora do intervalo. Preço: R$ 4.817,49
#                                                 nome        preco  \
# 0  PC Gamer U3, Ryzen 5 5600g, GeForce RTX 3060, ...  R$ 4.399,89
# 1  Placa de Video NVIDIA GeForce RTX 3060 12 GB G...  R$ 4.441,10
# 2  GIGABYTE Placa de vídeo GeForce RTX 3060 Gamin...  R$ 4.499,00
#
#                                                 link
# 0  https://www.google.com/url?url=https://www.loj...
# 1  https://www.buscape.com.br/placa-de-video/plac...
# 2  https://www.buscape.com.br/lead?oid=546338771&...
# Email do produto rtx 3060 enviado
